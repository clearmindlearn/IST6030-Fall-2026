# %%
# Section 2.1
x = 2
# variable name is x, value --> 2
print (x)
# Out:
# 2

# %%
x = "Hi Everyone"
print(x)
# Out:
# Hi Everyone

# %% [markdown]
# # Section 2.3

# %%
y = 2
print(type(y))
print (id(y))
# Out:
# <class 'int'>
# 11277960

# %%
z = "Hi"
print(type(z))
# Out:
# <class 'str'>

# %%
k = 3.1456
print(type(k))
# Out:
# <class 'float'>

# %%
a = True
print(type(a))
# Out:
# <class 'bool'>

# %% [markdown]
# #Section 2.4

# %%
#ask a user to enter .. in feet

print("Enter input (feet)")
feet = int(input())

inches = feet * 12

print("inches:", inches )
# Out:
# Enter input (feet)
# 2
# inches: 24

# %% [markdown]
# #Section 2.5

# %%
age = 10
age = age + 10

print(age)
# Out:
# 20

# %%
age = 10
age += 10
print (age)
# Out:
# 20

# %% [markdown]
# #2.7 and 2.8

# %%
9/3 #division
# Out:
# 3.0

# %%
#floor division --> round down the result
5.0 // 2
# Out:
# 2.0

# %%
print(9 % 2)  #evaluates the remainder of the division of two integer operands
# Out:
# 1

# %% [markdown]
# #2.6

# %%
 g = 10
 m = 10
 d = 10

 result = (g * m) / (d*d)
 print (result)
# Out:
# 1.0

# %%
result = (g*m)/ (d**2)  # ntoe that d**2 is same as d^2
print (result)
# Out:
# 1.0

# %%
#d ^3
d*d*d or d**3
