# %%
miles_gallon = float(input())
dollar_gallon = float(input())
# Out:
# 25.0
# 3.1599

# %%
#compute gas_cost_20
gas_cost_20 = 20 * dollar_gallon/miles_gallon
print(f"{gas_cost_20:.2f}")
# Out:
# 2.53
